# %% [markdown]
# <a href="https://colab.research.google.com/github/suyash091/Covid-19-diagnosis-engine/blob/master/best_of_COVID_X_ray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone 'https://github.com/suyash091/covid-chestxray-dataset'
# !git clone https://github.com/qubvel/efficientnet.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 820 (delta 4), reused 0 (delta 0), pack-reused 769
# Receiving objects: 100% (820/820), 152.42 MiB | 27.11 MiB/s, done.
# Resolving deltas: 100% (242/242), done.
# Cloning into 'efficientnet'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 292 (delta 4), reused 5 (delta 1), pack-reused 280
# Receiving objects: 100% (292/292), 835.16 KiB | 12.85 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
from numpy.random import seed
import random
seed(42)
import os
os.environ['PYTHONHASHSEED'] = str(42)
random.seed(42)
from tensorflow import set_random_seed
set_random_seed(42)

import efficientnet.efficientnet.keras as efn
import pandas as pd
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout, BatchNormalization
import numpy as np
import keras
from keras.optimizers import SGD, adam, Adadelta

# %%
def target(string):
  if string=='COVID-19':
    return string
  elif string=='No Finding':
    return 'Nothing'
  else:
    return "Others"

# %%
df=pd.read_csv('/content/covid-chestxray-dataset/metadata.csv')
df= df[['filename','finding']]
df['finding']=df['finding'].apply(target)
dfother=pd.read_csv('/content/covid-chestxray-dataset/Others.csv')
dfother.index +=len(df)
dfnothing=pd.read_csv('/content/covid-chestxray-dataset/Nothing.csv')
dfnothing.index +=int(len(df)+len(dfother))
dfbal=pd.read_csv('/content/covid-chestxray-dataset/added.csv')
dfbal.index +=int(len(df)+len(dfother)+len(dfnothing))

# %%
frames = [df, dfother, dfnothing, dfbal]

df = pd.concat(frames)
df= df[['filename','finding']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.describe()
# Out:
#                           filename finding
# count                          365     365
# unique                         364       3
# top     person1003_virus_1685.jpeg  Others
# freq                             2     123

# %%
len(df)
# Out:
# 365

# %%
df.finding.unique()
# Out:
# array(['COVID-19', 'Others', 'Nothing'], dtype=object)

# %%
len(df[df['finding']=='COVID-19'])-len(df[df['finding']=='Others'])
# Out:
# -2

# %%
from keras_preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        rescale=1./255,
        horizontal_flip=True,
        vertical_flip=True,
        validation_split=0.1)

#test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_dataframe(
        dataframe=df,
        directory='/content/covid-chestxray-dataset/images',
        x_col="filename",
        y_col='finding',
        target_size=(1024, 1024),
        batch_size=16,
        subset = 'training' ,
        class_mode='categorical')

validation_generator = datagen.flow_from_dataframe(
        dataframe=df,
        directory='/content/covid-chestxray-dataset/images',
        x_col="filename",
        y_col='finding',
        target_size=(1024, 1024),
        batch_size=16,
        subset="validation",
        class_mode='categorical')
# Out:
# Found 328 validated image filenames belonging to 3 classes.
# Found 36 validated image filenames belonging to 3 classes.
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 1 invalid image filename(s) in x_col="filename". These filename(s) will be ignored.
#   .format(n_invalid, x_col)

# %%
efficient_net = efn.EfficientNetB7(
    weights='imagenet',
    input_shape=(1024,1024,3),
    include_top=False
)
efficient_net.trainable = False
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.5125 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.525 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5375 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5625 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 2s 0us/step

# %%
efficient_net.summary()
# Out:
# Model: "efficientnet-b7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 1024, 1024, 3 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 512, 512, 64) 1728        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 512, 512, 64) 256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 512, 512, 64) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 512, 512, 64) 576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 512, 512, 64) 256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 512, 512, 64) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 512, 512, 64) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 512, 512, 32) 2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 512, 512, 32) 128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 512, 512, 32) 288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 512, 512, 32) 128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 512, 512, 32) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 512, 512, 32) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 512, 512, 32) 1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 512, 512, 32) 128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (FixedDropout)     (None, 512, 512, 32) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 512, 512, 32) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 512, 512, 32) 288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 512, 512, 32) 128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 512, 512, 32) 0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 512, 512, 32) 0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 512, 512, 32) 1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 512, 512, 32) 128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (FixedDropout)     (None, 512, 512, 32) 0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 512, 512, 32) 0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 512, 512, 32) 288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 512, 512, 32) 128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 512, 512, 32) 0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 512, 512, 32) 0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 512, 512, 32) 1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 512, 512, 32) 128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (FixedDropout)     (None, 512, 512, 32) 0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 512, 512, 32) 0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 512, 512, 192 6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 512, 512, 192 768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 512, 512, 192 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 256, 256, 192 1728        block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 256, 256, 192 768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 256, 256, 192 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 256, 256, 192 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 256, 256, 48) 9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 256, 256, 48) 192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 256, 256, 288 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 256, 256, 288 1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 256, 256, 288 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 256, 256, 288 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 256, 256, 48) 192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, 256, 256, 48) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 256, 256, 48) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 256, 256, 288 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 256, 256, 288 1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 256, 256, 288 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 256, 256, 288 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 256, 256, 48) 192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (FixedDropout)     (None, 256, 256, 48) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 256, 256, 48) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 256, 256, 288 0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 256, 256, 288 1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 256, 256, 288 0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 256, 256, 288 0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 256, 256, 48) 192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (FixedDropout)     (None, 256, 256, 48) 0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 256, 256, 48) 0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 256, 256, 288 0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 256, 256, 288 1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 256, 256, 288 0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 256, 256, 288 0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 256, 256, 48) 192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (FixedDropout)     (None, 256, 256, 48) 0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 256, 256, 48) 0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 256, 256, 288 0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 256, 256, 288 1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 256, 256, 288 0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 256, 256, 288 0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 256, 256, 48) 192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (FixedDropout)     (None, 256, 256, 48) 0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 256, 256, 48) 0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 256, 256, 288 1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 256, 256, 288 0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 256, 256, 288 2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 256, 256, 288 1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 256, 256, 288 0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 256, 256, 288 0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 256, 256, 48) 13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 256, 256, 48) 192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (FixedDropout)     (None, 256, 256, 48) 0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 256, 256, 48) 0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 256, 256, 288 13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 256, 256, 288 1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 256, 256, 288 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 128, 128, 288 7200        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 128, 128, 288 1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 128, 128, 288 0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 128, 128, 288 0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 128, 128, 80) 23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 128, 128, 80) 320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 128, 128, 480 38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 128, 128, 480 1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 128, 128, 480 0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 128, 128, 480 12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 128, 128, 480 1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 128, 128, 480 0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 128, 128, 480 0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 128, 128, 80) 38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 128, 128, 80) 320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, 128, 128, 80) 0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 128, 128, 80) 0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 128, 128, 480 38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 128, 128, 480 1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 128, 128, 480 0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 128, 128, 480 12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 128, 128, 480 1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 128, 128, 480 0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 128, 128, 480 0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 128, 128, 80) 38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 128, 128, 80) 320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (FixedDropout)     (None, 128, 128, 80) 0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 128, 128, 80) 0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 128, 128, 480 38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 128, 128, 480 1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 128, 128, 480 0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 128, 128, 480 12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 128, 128, 480 1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 128, 128, 480 0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 128, 128, 480 0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 128, 128, 80) 38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 128, 128, 80) 320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (FixedDropout)     (None, 128, 128, 80) 0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 128, 128, 80) 0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 128, 128, 480 38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 128, 128, 480 1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 128, 128, 480 0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 128, 128, 480 12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 128, 128, 480 1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 128, 128, 480 0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 128, 128, 480 0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# __________________________________________________________________________________________________
# block3e_project_conv (Conv2D)   (None, 128, 128, 80) 38400       block3e_se_excite[0][0]
# __________________________________________________________________________________________________
# block3e_project_bn (BatchNormal (None, 128, 128, 80) 320         block3e_project_conv[0][0]
# __________________________________________________________________________________________________
# block3e_drop (FixedDropout)     (None, 128, 128, 80) 0           block3e_project_bn[0][0]
# __________________________________________________________________________________________________
# block3e_add (Add)               (None, 128, 128, 80) 0           block3e_drop[0][0]
#                                                                  block3d_add[0][0]
# __________________________________________________________________________________________________
# ...
# block6m_expand_bn (BatchNormali (None, 32, 32, 2304) 9216        block6m_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6m_expand_activation (Acti (None, 32, 32, 2304) 0           block6m_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6m_dwconv (DepthwiseConv2D (None, 32, 32, 2304) 57600       block6m_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6m_bn (BatchNormalization) (None, 32, 32, 2304) 9216        block6m_dwconv[0][0]
# __________________________________________________________________________________________________
# block6m_activation (Activation) (None, 32, 32, 2304) 0           block6m_bn[0][0]
# __________________________________________________________________________________________________
# block6m_se_squeeze (GlobalAvera (None, 2304)         0           block6m_activation[0][0]
# __________________________________________________________________________________________________
# block6m_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block6m_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6m_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block6m_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6m_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block6m_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6m_se_excite (Multiply)    (None, 32, 32, 2304) 0           block6m_activation[0][0]
#                                                                  block6m_se_expand[0][0]
# __________________________________________________________________________________________________
# block6m_project_conv (Conv2D)   (None, 32, 32, 384)  884736      block6m_se_excite[0][0]
# __________________________________________________________________________________________________
# block6m_project_bn (BatchNormal (None, 32, 32, 384)  1536        block6m_project_conv[0][0]
# __________________________________________________________________________________________________
# block6m_drop (FixedDropout)     (None, 32, 32, 384)  0           block6m_project_bn[0][0]
# __________________________________________________________________________________________________
# block6m_add (Add)               (None, 32, 32, 384)  0           block6m_drop[0][0]
#                                                                  block6l_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 32, 32, 2304) 884736      block6m_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 32, 32, 2304) 9216        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 32, 32, 2304) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 32, 32, 2304) 20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 32, 32, 2304) 9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 32, 32, 2304) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 32, 32, 2304) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 32, 32, 640)  1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 32, 32, 640)  2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 32, 32, 3840) 2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 32, 32, 3840) 15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 32, 32, 3840) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 32, 32, 3840) 34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 32, 32, 3840) 15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 32, 32, 3840) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 32, 32, 3840) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 32, 32, 640)  2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 32, 32, 640)  2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (FixedDropout)     (None, 32, 32, 640)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 32, 32, 640)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 32, 32, 3840) 2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 32, 32, 3840) 15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 32, 32, 3840) 0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 32, 32, 3840) 34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 32, 32, 3840) 15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 32, 32, 3840) 0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 32, 32, 3840) 0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 32, 32, 640)  2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 32, 32, 640)  2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (FixedDropout)     (None, 32, 32, 640)  0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 32, 32, 640)  0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 32, 32, 3840) 2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 32, 32, 3840) 15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 32, 32, 3840) 0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 32, 32, 3840) 34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 32, 32, 3840) 15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 32, 32, 3840) 0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 32, 32, 3840) 0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 32, 32, 640)  2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 32, 32, 640)  2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (FixedDropout)     (None, 32, 32, 640)  0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 32, 32, 640)  0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 32, 32, 2560) 1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 32, 32, 2560) 10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 32, 32, 2560) 0           top_bn[0][0]
# ==================================================================================================
# Total params: 64,097,680
# Trainable params: 0
# Non-trainable params: 64,097,680
# __________________________________________________________________________________________________

# %%
set_trainable = False
for layer in efficient_net.layers:
    if layer.name == 'block7a_expand_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
for layer in efficient_net.layers:
    if layer.trainable == True:
        print('yeah baby!')
    else:
      print('naah! :(')
# Out:
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# naah! :(
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!
# yeah baby!

# %%
from keras.layers import AveragePooling2D
from keras.layers import Dropout
from keras.layers import Flatten

# %%
import tensorflow as tf
B = tf.keras.backend

@tf.function(experimental_relax_shapes=True)
def gelu(x):
    return 0.5 * x * (1 + B.tanh(x * 0.7978845608 * (1 + 0.044715 * x * x)))

@tf.function
def fast_gelu(x):
    return B.hard_sigmoid(1.702 * x) * x

# %%
from keras import backend as K

def swish(x, beta=1.0):
    return x * K.sigmoid(beta * x)

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# AveragePooling + Flatten

# %%
##CNN + FC 256 x 1 + AP + FLatten + Leakyrelu
model = Sequential()
model.add(efficient_net)
model.add(AveragePooling2D(pool_size=(4, 4)))
model.add(Flatten(name="flatten"))
#model.add(Dropout(0.5))
#model.add(Dense(units = 8192))
#model.add(keras.layers.LeakyReLU(alpha=0.3))
#model.add(Dropout(0.4))
model.add(Dense(units = 256))
model.add(keras.layers.LeakyReLU(alpha=0.3))
model.add(Dropout(0.5))
model.add(Dense(units = 3, activation ='softmax'))
opt = adam(lr=0.00001, amsgrad=True)
model.compile(optimizer= opt, loss='categorical_crossentropy', metrics=['accuracy',f1_m,precision_m, recall_m]) #sparse_categorical_crossentropy for sequence
saver = keras.callbacks.ModelCheckpoint('/content/cnnfcfinal.h5', save_best_only=True, monitor='val_acc', mode='max', save_weights_only=False, period=1)

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
model.fit_generator(train_generator, callbacks=[saver], steps_per_epoch=STEP_SIZE_TRAIN, validation_steps=STEP_SIZE_VALID, epochs=5000, validation_data = validation_generator, use_multiprocessing=True)
## train max == 0.9594 val == 0.8000
# Out:
# Epoch 1/5000
# 20/20 [==============================] - 75s 4s/step - loss: 0.9543 - acc: 0.5626 - f1_m: 0.5619 - precision_m: 0.6161 - recall_m: 0.5219 - val_loss: 0.7247 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 2/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.6533 - acc: 0.7688 - f1_m: 0.7474 - precision_m: 0.7768 - recall_m: 0.7220 - val_loss: 0.6844 - val_acc: 0.8500 - val_f1_m: 0.7900 - val_precision_m: 0.8357 - val_recall_m: 0.7500
# Epoch 3/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.5915 - acc: 0.7846 - f1_m: 0.7877 - precision_m: 0.8207 - recall_m: 0.7595 - val_loss: 0.7921 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 4/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.4841 - acc: 0.8187 - f1_m: 0.8185 - precision_m: 0.8457 - recall_m: 0.7938 - val_loss: 0.7988 - val_acc: 0.6875 - val_f1_m: 0.6673 - val_precision_m: 0.6792 - val_recall_m: 0.6562
# Epoch 5/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.4048 - acc: 0.8468 - f1_m: 0.8409 - precision_m: 0.8619 - recall_m: 0.8220 - val_loss: 0.8755 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 6/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.3831 - acc: 0.8626 - f1_m: 0.8579 - precision_m: 0.8764 - recall_m: 0.8407 - val_loss: 0.7448 - val_acc: 0.6000 - val_f1_m: 0.6145 - val_precision_m: 0.6300 - val_recall_m: 0.6000
# Epoch 7/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.3730 - acc: 0.8656 - f1_m: 0.8652 - precision_m: 0.8748 - recall_m: 0.8562 - val_loss: 0.6692 - val_acc: 0.5625 - val_f1_m: 0.5625 - val_precision_m: 0.5625 - val_recall_m: 0.5625
# Epoch 8/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.2869 - acc: 0.8844 - f1_m: 0.8861 - precision_m: 0.8946 - recall_m: 0.8781 - val_loss: 0.8234 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 9/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.3279 - acc: 0.9000 - f1_m: 0.8954 - precision_m: 0.9112 - recall_m: 0.8813 - val_loss: 0.8734 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 10/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.2928 - acc: 0.8875 - f1_m: 0.8878 - precision_m: 0.9055 - recall_m: 0.8719 - val_loss: 0.7009 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 11/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.2784 - acc: 0.8936 - f1_m: 0.8967 - precision_m: 0.9071 - recall_m: 0.8874 - val_loss: 0.7299 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 12/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.2463 - acc: 0.9000 - f1_m: 0.9007 - precision_m: 0.9084 - recall_m: 0.8938 - val_loss: 0.9645 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 13/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.3274 - acc: 0.8750 - f1_m: 0.8753 - precision_m: 0.8823 - recall_m: 0.8687 - val_loss: 0.8161 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 14/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.2506 - acc: 0.9187 - f1_m: 0.9162 - precision_m: 0.9270 - recall_m: 0.9063 - val_loss: 0.9562 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 15/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.2285 - acc: 0.9219 - f1_m: 0.9160 - precision_m: 0.9263 - recall_m: 0.9063 - val_loss: 0.7702 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 16/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1932 - acc: 0.9531 - f1_m: 0.9510 - precision_m: 0.9556 - recall_m: 0.9468 - val_loss: 0.7157 - val_acc: 0.7188 - val_f1_m: 0.7125 - val_precision_m: 0.7411 - val_recall_m: 0.6875
# Epoch 17/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.2115 - acc: 0.9159 - f1_m: 0.9187 - precision_m: 0.9319 - recall_m: 0.9065 - val_loss: 0.9589 - val_acc: 0.6500 - val_f1_m: 0.6161 - val_precision_m: 0.6333 - val_recall_m: 0.6000
# Epoch 18/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.2648 - acc: 0.9062 - f1_m: 0.9131 - precision_m: 0.9204 - recall_m: 0.9062 - val_loss: 0.7177 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 19/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.2135 - acc: 0.9374 - f1_m: 0.9363 - precision_m: 0.9453 - recall_m: 0.9280 - val_loss: 0.7119 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 20/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1875 - acc: 0.9312 - f1_m: 0.9300 - precision_m: 0.9424 - recall_m: 0.9187 - val_loss: 0.7327 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 21/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.2004 - acc: 0.9125 - f1_m: 0.9056 - precision_m: 0.9115 - recall_m: 0.9000 - val_loss: 0.8346 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 22/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1616 - acc: 0.9532 - f1_m: 0.9530 - precision_m: 0.9561 - recall_m: 0.9501 - val_loss: 0.7095 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 23/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.2051 - acc: 0.9281 - f1_m: 0.9264 - precision_m: 0.9279 - recall_m: 0.9250 - val_loss: 0.4241 - val_acc: 0.9000 - val_f1_m: 0.9000 - val_precision_m: 0.9000 - val_recall_m: 0.9000
# Epoch 24/5000
#  1/20 [>.............................] - ETA: 24s - loss: 0.1492 - acc: 0.8750 - f1_m: 0.8750 - precision_m: 0.8750 - recall_m: 0.8750
# 20/20 [==============================] - 51s 3s/step - loss: 0.1931 - acc: 0.9284 - f1_m: 0.9312 - precision_m: 0.9378 - recall_m: 0.9253 - val_loss: 1.0241 - val_acc: 0.5500 - val_f1_m: 0.5677 - val_precision_m: 0.5867 - val_recall_m: 0.5500
# Epoch 25/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1688 - acc: 0.9377 - f1_m: 0.9367 - precision_m: 0.9425 - recall_m: 0.9315 - val_loss: 1.2303 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 26/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1740 - acc: 0.9438 - f1_m: 0.9380 - precision_m: 0.9487 - recall_m: 0.9281 - val_loss: 0.7705 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 27/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.1651 - acc: 0.9593 - f1_m: 0.9541 - precision_m: 0.9586 - recall_m: 0.9499 - val_loss: 0.9452 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 28/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1533 - acc: 0.9499 - f1_m: 0.9480 - precision_m: 0.9527 - recall_m: 0.9437 - val_loss: 0.8193 - val_acc: 0.7188 - val_f1_m: 0.7187 - val_precision_m: 0.7188 - val_recall_m: 0.7188
# Epoch 29/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1520 - acc: 0.9501 - f1_m: 0.9400 - precision_m: 0.9497 - recall_m: 0.9313 - val_loss: 1.2328 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 30/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.1582 - acc: 0.9499 - f1_m: 0.9524 - precision_m: 0.9618 - recall_m: 0.9437 - val_loss: 0.7841 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 31/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.1412 - acc: 0.9656 - f1_m: 0.9652 - precision_m: 0.9715 - recall_m: 0.9594 - val_loss: 1.0919 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 32/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1434 - acc: 0.9376 - f1_m: 0.9414 - precision_m: 0.9457 - recall_m: 0.9376 - val_loss: 1.7603 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 33/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.1042 - acc: 0.9656 - f1_m: 0.9638 - precision_m: 0.9652 - recall_m: 0.9625 - val_loss: 0.4449 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 34/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1198 - acc: 0.9593 - f1_m: 0.9573 - precision_m: 0.9652 - recall_m: 0.9501 - val_loss: 1.0630 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 35/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.1009 - acc: 0.9626 - f1_m: 0.9637 - precision_m: 0.9715 - recall_m: 0.9563 - val_loss: 0.6731 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 36/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.1123 - acc: 0.9656 - f1_m: 0.9653 - precision_m: 0.9717 - recall_m: 0.9594 - val_loss: 1.0815 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 37/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1177 - acc: 0.9501 - f1_m: 0.9542 - precision_m: 0.9620 - recall_m: 0.9470 - val_loss: 1.1620 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 38/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1084 - acc: 0.9562 - f1_m: 0.9590 - precision_m: 0.9620 - recall_m: 0.9562 - val_loss: 0.7202 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 39/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.1064 - acc: 0.9655 - f1_m: 0.9638 - precision_m: 0.9653 - recall_m: 0.9624 - val_loss: 0.9124 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 40/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0751 - acc: 0.9781 - f1_m: 0.9796 - precision_m: 0.9812 - recall_m: 0.9781 - val_loss: 1.3670 - val_acc: 0.5938 - val_f1_m: 0.5937 - val_precision_m: 0.5938 - val_recall_m: 0.5938
# Epoch 41/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0747 - acc: 0.9906 - f1_m: 0.9873 - precision_m: 0.9937 - recall_m: 0.9812 - val_loss: 0.7943 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 42/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.1552 - acc: 0.9410 - f1_m: 0.9377 - precision_m: 0.9441 - recall_m: 0.9316 - val_loss: 1.2131 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 43/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1352 - acc: 0.9656 - f1_m: 0.9640 - precision_m: 0.9656 - recall_m: 0.9625 - val_loss: 0.8199 - val_acc: 0.6875 - val_f1_m: 0.6986 - val_precision_m: 0.7104 - val_recall_m: 0.6875
# Epoch 44/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.1083 - acc: 0.9687 - f1_m: 0.9702 - precision_m: 0.9718 - recall_m: 0.9687 - val_loss: 1.1235 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 45/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.1247 - acc: 0.9656 - f1_m: 0.9655 - precision_m: 0.9687 - recall_m: 0.9625 - val_loss: 1.3463 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 46/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.1054 - acc: 0.9689 - f1_m: 0.9672 - precision_m: 0.9689 - recall_m: 0.9657 - val_loss: 0.8594 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 47/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0859 - acc: 0.9721 - f1_m: 0.9721 - precision_m: 0.9721 - recall_m: 0.9721 - val_loss: 0.7906 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 48/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.1167 - acc: 0.9625 - f1_m: 0.9625 - precision_m: 0.9625 - recall_m: 0.9625 - val_loss: 1.3248 - val_acc: 0.7000 - val_f1_m: 0.6571 - val_precision_m: 0.6667 - val_recall_m: 0.6500
# Epoch 49/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.1683 - acc: 0.9406 - f1_m: 0.9420 - precision_m: 0.9435 - recall_m: 0.9406 - val_loss: 0.8421 - val_acc: 0.7500 - val_f1_m: 0.7268 - val_precision_m: 0.7354 - val_recall_m: 0.7188
# Epoch 50/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0992 - acc: 0.9687 - f1_m: 0.9687 - precision_m: 0.9687 - recall_m: 0.9687 - val_loss: 1.3396 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 51/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0841 - acc: 0.9718 - f1_m: 0.9718 - precision_m: 0.9718 - recall_m: 0.9718 - val_loss: 1.1466 - val_acc: 0.7000 - val_f1_m: 0.6645 - val_precision_m: 0.6800 - val_recall_m: 0.6500
# Epoch 52/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0813 - acc: 0.9656 - f1_m: 0.9685 - precision_m: 0.9716 - recall_m: 0.9656 - val_loss: 1.6142 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 53/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1671 - acc: 0.9440 - f1_m: 0.9440 - precision_m: 0.9440 - recall_m: 0.9440 - val_loss: 1.0563 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 54/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0879 - acc: 0.9718 - f1_m: 0.9702 - precision_m: 0.9718 - recall_m: 0.9687 - val_loss: 1.0851 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 55/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0688 - acc: 0.9812 - f1_m: 0.9811 - precision_m: 0.9844 - recall_m: 0.9781 - val_loss: 0.7799 - val_acc: 0.6875 - val_f1_m: 0.6673 - val_precision_m: 0.6792 - val_recall_m: 0.6562
# Epoch 56/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0706 - acc: 0.9781 - f1_m: 0.9779 - precision_m: 0.9810 - recall_m: 0.9749 - val_loss: 1.1344 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 57/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0669 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.0401 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 58/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0448 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.3294 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 59/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1072 - acc: 0.9656 - f1_m: 0.9700 - precision_m: 0.9748 - recall_m: 0.9656 - val_loss: 1.0036 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 60/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.0976 - acc: 0.9627 - f1_m: 0.9642 - precision_m: 0.9659 - recall_m: 0.9627 - val_loss: 1.2917 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 61/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.1053 - acc: 0.9688 - f1_m: 0.9686 - precision_m: 0.9719 - recall_m: 0.9656 - val_loss: 1.3905 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 62/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0984 - acc: 0.9687 - f1_m: 0.9686 - precision_m: 0.9718 - recall_m: 0.9656 - val_loss: 0.7911 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 63/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0620 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.3533 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 64/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0914 - acc: 0.9687 - f1_m: 0.9702 - precision_m: 0.9718 - recall_m: 0.9687 - val_loss: 1.1868 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 65/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0659 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 1.0570 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 66/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0509 - acc: 0.9875 - f1_m: 0.9874 - precision_m: 0.9906 - recall_m: 0.9844 - val_loss: 1.6978 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 67/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0692 - acc: 0.9750 - f1_m: 0.9750 - precision_m: 0.9750 - recall_m: 0.9750 - val_loss: 1.4366 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 68/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0570 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.2462 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 69/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0577 - acc: 0.9781 - f1_m: 0.9765 - precision_m: 0.9781 - recall_m: 0.9750 - val_loss: 0.8114 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 70/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0763 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.5286 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 71/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0529 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.4090 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 72/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0560 - acc: 0.9812 - f1_m: 0.9809 - precision_m: 0.9839 - recall_m: 0.9781 - val_loss: 1.4512 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 73/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0429 - acc: 0.9844 - f1_m: 0.9842 - precision_m: 0.9873 - recall_m: 0.9812 - val_loss: 1.2642 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 74/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0472 - acc: 0.9845 - f1_m: 0.9829 - precision_m: 0.9845 - recall_m: 0.9814 - val_loss: 1.3652 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 75/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0790 - acc: 0.9594 - f1_m: 0.9609 - precision_m: 0.9625 - recall_m: 0.9594 - val_loss: 1.1591 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 76/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0669 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.2075 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 77/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0692 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 1.9406 - val_acc: 0.6000 - val_f1_m: 0.5645 - val_precision_m: 0.5800 - val_recall_m: 0.5500
# Epoch 78/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0705 - acc: 0.9720 - f1_m: 0.9720 - precision_m: 0.9720 - recall_m: 0.9720 - val_loss: 1.0009 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 79/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0648 - acc: 0.9753 - f1_m: 0.9753 - precision_m: 0.9753 - recall_m: 0.9753 - val_loss: 1.2822 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 80/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0945 - acc: 0.9719 - f1_m: 0.9702 - precision_m: 0.9717 - recall_m: 0.9688 - val_loss: 1.7598 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 81/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.1698 - acc: 0.9690 - f1_m: 0.9715 - precision_m: 0.9742 - recall_m: 0.9690 - val_loss: 1.3231 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 82/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1326 - acc: 0.9625 - f1_m: 0.9625 - precision_m: 0.9625 - recall_m: 0.9625 - val_loss: 1.1134 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 83/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0694 - acc: 0.9689 - f1_m: 0.9672 - precision_m: 0.9689 - recall_m: 0.9657 - val_loss: 1.8031 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 84/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0693 - acc: 0.9718 - f1_m: 0.9733 - precision_m: 0.9748 - recall_m: 0.9718 - val_loss: 0.6696 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 85/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0860 - acc: 0.9689 - f1_m: 0.9689 - precision_m: 0.9689 - recall_m: 0.9689 - val_loss: 1.2739 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 86/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0574 - acc: 0.9844 - f1_m: 0.9810 - precision_m: 0.9875 - recall_m: 0.9751 - val_loss: 1.1143 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 87/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0789 - acc: 0.9687 - f1_m: 0.9702 - precision_m: 0.9718 - recall_m: 0.9687 - val_loss: 1.1591 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 88/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.1276 - acc: 0.9656 - f1_m: 0.9656 - precision_m: 0.9656 - recall_m: 0.9656 - val_loss: 1.0636 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 89/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0540 - acc: 0.9812 - f1_m: 0.9827 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 1.6970 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 90/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0459 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.3412 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 91/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0419 - acc: 0.9844 - f1_m: 0.9826 - precision_m: 0.9841 - recall_m: 0.9812 - val_loss: 1.1447 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 92/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0575 - acc: 0.9844 - f1_m: 0.9844 - precision_m: 0.9844 - recall_m: 0.9844 - val_loss: 2.0702 - val_acc: 0.5500 - val_f1_m: 0.5500 - val_precision_m: 0.5500 - val_recall_m: 0.5500
# Epoch 93/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0546 - acc: 0.9844 - f1_m: 0.9810 - precision_m: 0.9842 - recall_m: 0.9781 - val_loss: 0.7574 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 94/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0639 - acc: 0.9844 - f1_m: 0.9842 - precision_m: 0.9873 - recall_m: 0.9812 - val_loss: 1.1451 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 95/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0343 - acc: 0.9937 - f1_m: 0.9953 - precision_m: 0.9969 - recall_m: 0.9937 - val_loss: 1.1486 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 96/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0619 - acc: 0.9781 - f1_m: 0.9796 - precision_m: 0.9812 - recall_m: 0.9781 - val_loss: 1.4163 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 97/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0630 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 1.0697 - val_acc: 0.6562 - val_f1_m: 0.6341 - val_precision_m: 0.6438 - val_recall_m: 0.6250
# Epoch 98/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0913 - acc: 0.9593 - f1_m: 0.9623 - precision_m: 0.9654 - recall_m: 0.9593 - val_loss: 1.0672 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 99/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0565 - acc: 0.9844 - f1_m: 0.9826 - precision_m: 0.9841 - recall_m: 0.9812 - val_loss: 1.1815 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 100/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0261 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.3198 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 101/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0295 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.9603 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 102/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0973 - acc: 0.9593 - f1_m: 0.9593 - precision_m: 0.9593 - recall_m: 0.9593 - val_loss: 0.5451 - val_acc: 0.8500 - val_f1_m: 0.8500 - val_precision_m: 0.8500 - val_recall_m: 0.8500
# Epoch 103/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0465 - acc: 0.9875 - f1_m: 0.9888 - precision_m: 0.9937 - recall_m: 0.9844 - val_loss: 1.2869 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 104/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0363 - acc: 0.9812 - f1_m: 0.9827 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 1.3778 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 105/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0325 - acc: 0.9906 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 0.9692 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 106/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0355 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.2128 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 107/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0490 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.5129 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 108/5000
#  1/20 [>.............................] - ETA: 46s - loss: 0.0122 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0687 - acc: 0.9718 - f1_m: 0.9714 - precision_m: 0.9743 - recall_m: 0.9687 - val_loss: 0.9847 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 109/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0280 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.1275 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 110/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0348 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.2283 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 111/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0279 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.1292 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 112/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0458 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.1416 - val_acc: 0.6875 - val_f1_m: 0.6956 - val_precision_m: 0.7042 - val_recall_m: 0.6875
# Epoch 113/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0344 - acc: 0.9937 - f1_m: 0.9921 - precision_m: 0.9937 - recall_m: 0.9906 - val_loss: 0.9521 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 114/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0248 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.2482 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 115/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0497 - acc: 0.9844 - f1_m: 0.9859 - precision_m: 0.9875 - recall_m: 0.9844 - val_loss: 1.2759 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 116/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0416 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 0.9524 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 117/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0544 - acc: 0.9782 - f1_m: 0.9796 - precision_m: 0.9812 - recall_m: 0.9782 - val_loss: 1.1028 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 118/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0569 - acc: 0.9718 - f1_m: 0.9718 - precision_m: 0.9718 - recall_m: 0.9718 - val_loss: 1.1769 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 119/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0356 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.6622 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 120/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.0593 - acc: 0.9782 - f1_m: 0.9781 - precision_m: 0.9814 - recall_m: 0.9751 - val_loss: 0.8338 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 121/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0481 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.0312 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 122/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0535 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.7045 - val_acc: 0.5500 - val_f1_m: 0.5500 - val_precision_m: 0.5500 - val_recall_m: 0.5500
# Epoch 123/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0355 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.1336 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 124/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0494 - acc: 0.9812 - f1_m: 0.9827 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 1.3837 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 125/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0317 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.1710 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 126/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0324 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.2564 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 127/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0427 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.0023 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 128/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0409 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.4480 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 129/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0412 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 0.5926 - val_acc: 0.8500 - val_f1_m: 0.8194 - val_precision_m: 0.8400 - val_recall_m: 0.8000
# Epoch 130/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0345 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.3519 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 131/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0649 - acc: 0.9687 - f1_m: 0.9702 - precision_m: 0.9718 - recall_m: 0.9687 - val_loss: 1.3306 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 132/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0206 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 0.9915 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 133/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0383 - acc: 0.9906 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 1.0236 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 134/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0349 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.6087 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 135/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0319 - acc: 0.9906 - f1_m: 0.9889 - precision_m: 0.9904 - recall_m: 0.9875 - val_loss: 1.1463 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 136/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0367 - acc: 0.9875 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 1.1124 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 137/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0490 - acc: 0.9781 - f1_m: 0.9796 - precision_m: 0.9812 - recall_m: 0.9781 - val_loss: 1.6512 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 138/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0556 - acc: 0.9781 - f1_m: 0.9796 - precision_m: 0.9812 - recall_m: 0.9781 - val_loss: 1.0226 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 139/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0521 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.0959 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 140/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0464 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.1092 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 141/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0371 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.2856 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 142/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0673 - acc: 0.9751 - f1_m: 0.9766 - precision_m: 0.9783 - recall_m: 0.9751 - val_loss: 1.4774 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 143/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0500 - acc: 0.9937 - f1_m: 0.9905 - precision_m: 0.9937 - recall_m: 0.9875 - val_loss: 1.4807 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 144/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.0304 - acc: 0.9906 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 0.7251 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 145/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0260 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.2176 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 146/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0447 - acc: 0.9844 - f1_m: 0.9844 - precision_m: 0.9844 - recall_m: 0.9844 - val_loss: 1.2758 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 147/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0305 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.0608 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 148/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0335 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.1767 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 149/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0278 - acc: 0.9906 - f1_m: 0.9921 - precision_m: 0.9937 - recall_m: 0.9906 - val_loss: 1.4152 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 150/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0308 - acc: 0.9906 - f1_m: 0.9905 - precision_m: 0.9937 - recall_m: 0.9875 - val_loss: 1.2473 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 151/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0582 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.5343 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 152/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0480 - acc: 0.9812 - f1_m: 0.9826 - precision_m: 0.9841 - recall_m: 0.9812 - val_loss: 1.7078 - val_acc: 0.5500 - val_f1_m: 0.5500 - val_precision_m: 0.5500 - val_recall_m: 0.5500
# Epoch 153/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0840 - acc: 0.9750 - f1_m: 0.9750 - precision_m: 0.9750 - recall_m: 0.9750 - val_loss: 0.6980 - val_acc: 0.8500 - val_f1_m: 0.8500 - val_precision_m: 0.8500 - val_recall_m: 0.8500
# Epoch 154/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0249 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.6493 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 155/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0233 - acc: 0.9969 - f1_m: 0.9984 - precision_m: 1.0000 - recall_m: 0.9969 - val_loss: 1.8299 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 156/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0470 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 0.5991 - val_acc: 0.7000 - val_f1_m: 0.6661 - val_precision_m: 0.6833 - val_recall_m: 0.6500
# Epoch 157/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0350 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.4068 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 158/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0516 - acc: 0.9782 - f1_m: 0.9797 - precision_m: 0.9814 - recall_m: 0.9782 - val_loss: 1.5137 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 159/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0375 - acc: 0.9844 - f1_m: 0.9827 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 1.0815 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 160/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0294 - acc: 0.9937 - f1_m: 0.9953 - precision_m: 0.9969 - recall_m: 0.9937 - val_loss: 1.4231 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 161/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0501 - acc: 0.9876 - f1_m: 0.9876 - precision_m: 0.9876 - recall_m: 0.9876 - val_loss: 1.2417 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 162/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0301 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.4814 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 163/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0126 - acc: 1.0000 - f1_m: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 1.5332 - val_acc: 0.6562 - val_f1_m: 0.6663 - val_precision_m: 0.6771 - val_recall_m: 0.6562
# Epoch 164/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0140 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.4725 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 165/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0172 - acc: 0.9937 - f1_m: 0.9953 - precision_m: 0.9969 - recall_m: 0.9937 - val_loss: 1.7035 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 166/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0155 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.6112 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 167/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0305 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 0.8039 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 168/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0346 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.7723 - val_acc: 0.5500 - val_f1_m: 0.5500 - val_precision_m: 0.5500 - val_recall_m: 0.5500
# Epoch 169/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0367 - acc: 0.9844 - f1_m: 0.9827 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 0.9939 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 170/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0355 - acc: 0.9844 - f1_m: 0.9844 - precision_m: 0.9844 - recall_m: 0.9844 - val_loss: 1.9439 - val_acc: 0.5500 - val_f1_m: 0.5500 - val_precision_m: 0.5500 - val_recall_m: 0.5500
# Epoch 171/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0185 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.2285 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 172/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0558 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 1.6543 - val_acc: 0.6250 - val_f1_m: 0.6351 - val_precision_m: 0.6458 - val_recall_m: 0.6250
# Epoch 173/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0351 - acc: 0.9844 - f1_m: 0.9844 - precision_m: 0.9844 - recall_m: 0.9844 - val_loss: 0.9972 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 174/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0422 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.2582 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 175/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0285 - acc: 0.9906 - f1_m: 0.9921 - precision_m: 0.9937 - recall_m: 0.9906 - val_loss: 1.1794 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 176/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0186 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.7770 - val_acc: 0.6000 - val_f1_m: 0.6000 - val_precision_m: 0.6000 - val_recall_m: 0.6000
# Epoch 177/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0170 - acc: 1.0000 - f1_m: 0.9984 - precision_m: 1.0000 - recall_m: 0.9969 - val_loss: 1.1570 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 178/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0389 - acc: 0.9812 - f1_m: 0.9828 - precision_m: 0.9844 - recall_m: 0.9812 - val_loss: 1.1151 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 179/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0174 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 2.0662 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 180/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0584 - acc: 0.9781 - f1_m: 0.9781 - precision_m: 0.9781 - recall_m: 0.9781 - val_loss: 1.1737 - val_acc: 0.7000 - val_f1_m: 0.6661 - val_precision_m: 0.6833 - val_recall_m: 0.6500
# Epoch 181/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0533 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.5982 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 182/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0488 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 1.3179 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 183/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0300 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.1974 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 184/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0387 - acc: 0.9814 - f1_m: 0.9814 - precision_m: 0.9814 - recall_m: 0.9814 - val_loss: 1.5995 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 185/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0246 - acc: 0.9937 - f1_m: 0.9921 - precision_m: 0.9937 - recall_m: 0.9906 - val_loss: 1.2251 - val_acc: 0.8000 - val_f1_m: 0.8000 - val_precision_m: 0.8000 - val_recall_m: 0.8000
# Epoch 186/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0373 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.9265 - val_acc: 0.5000 - val_f1_m: 0.5000 - val_precision_m: 0.5000 - val_recall_m: 0.5000
# Epoch 187/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0263 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.4788 - val_acc: 0.6250 - val_f1_m: 0.6250 - val_precision_m: 0.6250 - val_recall_m: 0.6250
# Epoch 188/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0218 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.3150 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 189/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0142 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.0170 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 190/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0241 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.5622 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 191/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0336 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 1.3765 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 192/5000
# 20/20 [==============================] - 50s 3s/step - loss: 0.0254 - acc: 0.9969 - f1_m: 0.9953 - precision_m: 0.9969 - recall_m: 0.9937 - val_loss: 1.7690 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 193/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0299 - acc: 0.9906 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 1.4574 - val_acc: 0.6250 - val_f1_m: 0.6038 - val_precision_m: 0.6146 - val_recall_m: 0.5938
# Epoch 194/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0258 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.6203 - val_acc: 0.7500 - val_f1_m: 0.7500 - val_precision_m: 0.7500 - val_recall_m: 0.7500
# Epoch 195/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0349 - acc: 0.9814 - f1_m: 0.9814 - precision_m: 0.9814 - recall_m: 0.9814 - val_loss: 1.9239 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 196/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0342 - acc: 0.9844 - f1_m: 0.9825 - precision_m: 0.9839 - recall_m: 0.9812 - val_loss: 1.6826 - val_acc: 0.6250 - val_f1_m: 0.6028 - val_precision_m: 0.6125 - val_recall_m: 0.5938
# Epoch 197/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0465 - acc: 0.9844 - f1_m: 0.9844 - precision_m: 0.9844 - recall_m: 0.9844 - val_loss: 1.9847 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 198/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0239 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.2026 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 199/5000
# 20/20 [==============================] - 55s 3s/step - loss: 0.0370 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875 - val_loss: 2.0293 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 200/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0183 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.3054 - val_acc: 0.7000 - val_f1_m: 0.7000 - val_precision_m: 0.7000 - val_recall_m: 0.7000
# Epoch 201/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0298 - acc: 0.9937 - f1_m: 0.9937 - precision_m: 0.9937 - recall_m: 0.9937 - val_loss: 1.7803 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 202/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0278 - acc: 0.9845 - f1_m: 0.9875 - precision_m: 0.9908 - recall_m: 0.9845 - val_loss: 1.8710 - val_acc: 0.6562 - val_f1_m: 0.6562 - val_precision_m: 0.6562 - val_recall_m: 0.6562
# Epoch 203/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0746 - acc: 0.9812 - f1_m: 0.9812 - precision_m: 0.9812 - recall_m: 0.9812 - val_loss: 2.5320 - val_acc: 0.5500 - val_f1_m: 0.5113 - val_precision_m: 0.5233 - val_recall_m: 0.5000
# Epoch 204/5000
# 20/20 [==============================] - 52s 3s/step - loss: 0.0346 - acc: 0.9876 - f1_m: 0.9892 - precision_m: 0.9908 - recall_m: 0.9876 - val_loss: 0.8477 - val_acc: 0.7500 - val_f1_m: 0.6800 - val_precision_m: 0.7143 - val_recall_m: 0.6500
# Epoch 205/5000
# 20/20 [==============================] - 53s 3s/step - loss: 0.0264 - acc: 0.9906 - f1_m: 0.9906 - precision_m: 0.9906 - recall_m: 0.9906 - val_loss: 1.3648 - val_acc: 0.6875 - val_f1_m: 0.6653 - val_precision_m: 0.6750 - val_recall_m: 0.6562
# Epoch 206/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0264 - acc: 0.9906 - f1_m: 0.9890 - precision_m: 0.9906 - recall_m: 0.9875 - val_loss: 1.9791 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 207/5000
# 20/20 [==============================] - 51s 3s/step - loss: 0.0203 - acc: 0.9937 - f1_m: 0.9953 - precision_m: 0.9969 - recall_m: 0.9937 - val_loss: 1.6720 - val_acc: 0.6500 - val_f1_m: 0.6500 - val_precision_m: 0.6500 - val_recall_m: 0.6500
# Epoch 208/5000
# 20/20 [==============================] - 54s 3s/step - loss: 0.0159 - acc: 0.9969 - f1_m: 0.9969 - precision_m: 0.9969 - recall_m: 0.9969 - val_loss: 1.6834 - val_acc: 0.6875 - val_f1_m: 0.6875 - val_precision_m: 0.6875 - val_recall_m: 0.6875
# Epoch 209/5000
# 10/20 [==============>...............] - ETA: 24s - loss: 0.0229 - acc: 0.9875 - f1_m: 0.9875 - precision_m: 0.9875 - recall_m: 0.9875
# Process ForkPoolWorker-506:
# Process ForkPoolWorker-505:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-708246941e5e> in <module>()
#      17 STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
#      18 STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size
# ---> 19 model.fit_generator(train_generator, callbacks=[saver], steps_per_epoch=STEP_SIZE_TRAIN, validation_steps=STEP_SIZE_VALID, epochs=5000, validation_data = validation_generator, use_multiprocessing=True)
#      20 ## train max == 0.9594 val == 0.8000
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     213                 outs = model.train_on_batch(x, y,
#     214                                             sample_weight=sample_weight,
# --> 215                                             class_weight=class_weight)
#     216
#     217                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1447             ins = x + y + sample_weights
#    1448         self._make_train_function()
# -> 1449         outputs = self.train_function(ins)
#    1450         return unpack_singleton(outputs)
#    1451
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
##CNN + FC II

# %%
##CNN + PCA + SVM

# %%
##CNN + PCA + KNN
